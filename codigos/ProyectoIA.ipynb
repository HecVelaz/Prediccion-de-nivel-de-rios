# %% [markdown]
# <a href="https://colab.research.google.com/github/HecVelaz/Prediccion-de-nivel-de-rios/blob/main/codigos/ProyectoIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IA/nivel_procesado_1904-2023(3).csv")
df1.shape
df1_copy=df1

# %% [markdown]
# 43545 registros en 26 columnas

# %%
df2=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/IA/caudales.xlsx")
df2.shape
df2_copy=df2

# %%
df1.info()
print("nulos")
df1.isnull().sum()#cantidad de ceros cada columna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43545 entries, 0 to 43544
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fecha     43545 non-null  object
#  1   valor009  2640 non-null   float64
#  2   valor010  19359 non-null  float64
#  3   valor033  33439 non-null  float64
#  4   valor088  18802 non-null  float64
#  5   valor134  41430 non-null  float64
#  6   valor183  33292 non-null  float64
#  7   valor184  1177 non-null   float64
#  8   valor191  196 non-null    float64
#  9   valor210  2357 non-null   float64
#  10  valor211  33249 non-null  float64
#  11  e218      43512 non-null  float64
#  12  valor219  1237 non-null   float64
#  13  valor248  2459 non-null   float64
#  14  valor252  1278 non-null   float64
#  15  valor253  1286 non-null   float64
#  16  valor254  12654 non-null  float64
#  17  valor255  33287 non-null  float64
#  18  valor257  2401 non-null   float64
# ...

# %%
df1
# Out:
#             valor009  valor010  valor033  valor088  valor134  valor183  \
# fecha
# 1904-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 1904-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 1904-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 1904-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 1904-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-03-17      5.40      5.76       NaN      5.35      6.29      6.12
# 2023-03-18      5.38      5.76       NaN      5.35      6.20      6.13
# 2023-03-19      5.38      5.74       NaN      5.37      6.10      6.14
# 2023-03-20      5.41      5.74       NaN      5.38      6.10      6.10
# 2023-03-21      5.41      5.74       NaN      5.36      6.00      6.10
#
#             valor184  valor191  valor210  valor211  ...  valor254  valor255  \
# ...

# %%
df1_copy
# Out:
#             valor009  valor010  valor033  valor088  valor134  valor183  \
# fecha
# 1904-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 1904-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 1904-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 1904-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 1904-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-03-17      5.40      5.76       NaN      5.35      6.29      6.12
# 2023-03-18      5.38      5.76       NaN      5.35      6.20      6.13
# 2023-03-19      5.38      5.74       NaN      5.37      6.10      6.14
# 2023-03-20      5.41      5.74       NaN      5.38      6.10      6.10
# 2023-03-21      5.41      5.74       NaN      5.36      6.00      6.10
#
#             valor184  valor191  valor210  valor211  ...  valor254  valor255  \
# ...

# %%
df1_copy['fecha'] = pd.to_datetime(df1_copy['fecha'])#formato fecha pandas
df1_copy.set_index('fecha',inplace=True)
datos_asuncion  = df1_copy['e218']
datos_asuncion
# Out:
# fecha
# 1904-01-01    5.12
# 1904-01-02    5.16
# 1904-01-03    5.09
# 1904-01-04    4.96
# 1904-01-05    4.90
#               ...
# 2023-03-17    4.97
# 2023-03-18    5.07
# 2023-03-19    5.15
# 2023-03-20    5.21
# 2023-03-21    5.26
# Name: e218, Length: 43545, dtype: float64

# %%
datos_asuncion.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 43545 entries, 1904-01-01 to 2023-03-21
# Series name: e218
# Non-Null Count  Dtype
# --------------  -----
# 43512 non-null  float64
# dtypes: float64(1)
# memory usage: 680.4 KB

# %% [markdown]
# 43545-43512= 33 Valores NULOS

# %%
datos_asuncion.isnull()
# Out:
# fecha
# 1904-01-01    False
# 1904-01-02    False
# 1904-01-03    False
# 1904-01-04    False
# 1904-01-05    False
#               ...
# 2023-03-17    False
# 2023-03-18    False
# 2023-03-19    False
# 2023-03-20    False
# 2023-03-21    False
# Name: e218, Length: 43545, dtype: bool

# %%
datos_asuncion
# Out:
# fecha
# 1904-01-01    5.12
# 1904-01-02    5.16
# 1904-01-03    5.09
# 1904-01-04    4.96
# 1904-01-05    4.90
#               ...
# 2023-03-17    4.97
# 2023-03-18    5.07
# 2023-03-19    5.15
# 2023-03-20    5.21
# 2023-03-21    5.26
# Name: e218, Length: 43545, dtype: float64

# %%
df2
# Out:
#          fecha  Caudal Murtinho   Caudal Asu  Pre Mur-asu
# 0   1964-01-01       968.246000  1176.081687    80.930864
# 1   1964-02-01      1071.408000  1385.956511   147.624691
# 2   1964-03-01      1222.863000  1785.974925   153.762963
# 3   1964-04-01      1283.062000  2858.595227   129.350617
# 4   1964-05-01      1241.180000  3302.944839    44.376543
# ..         ...              ...          ...          ...
# 716 2023-09-01      2144.340303  2312.861567          NaN
# 717 2023-10-01      1525.528995  1746.917482          NaN
# 718 2023-11-01       884.912627  1660.776897          NaN
# 719 2023-12-01       848.791718  2010.392624          NaN
# 720 2024-01-01       809.924216  1354.321885          NaN
#
# [721 rows x 4 columns]
