# %%
import pandas as pd
import numpy as np
import time
import datetime as dt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from keras.metrics import RootMeanSquaredError
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error,max_error
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,Callback
from tensorflow.keras.optimizers import Adam
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import pyplot as plt
from tensorflow.keras.models import load_model,model_from_json
from matplotlib.gridspec import GridSpec
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IA/nivel_procesado_1904-2023.csv")
df1.shape
df1_copy=df1

# %%
df2=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/IA/caudales.xlsx")
df2.shape
df2_copy=df2

# %%
df1.info()
print("nulos")
df1.isnull().sum()#cantidad de ceros cada columna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43545 entries, 0 to 43544
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fecha     43545 non-null  object
#  1   valor009  2640 non-null   float64
#  2   valor010  19359 non-null  float64
#  3   valor033  33439 non-null  float64
#  4   valor088  18802 non-null  float64
#  5   valor134  41430 non-null  float64
#  6   valor183  33292 non-null  float64
#  7   valor184  1177 non-null   float64
#  8   valor191  196 non-null    float64
#  9   valor210  2357 non-null   float64
#  10  valor211  33249 non-null  float64
#  11  e218      43512 non-null  float64
#  12  valor219  1237 non-null   float64
#  13  valor248  2459 non-null   float64
#  14  valor252  1278 non-null   float64
#  15  valor253  1286 non-null   float64
#  16  valor254  12654 non-null  float64
#  17  valor255  33287 non-null  float64
#  18  valor257  2401 non-null   float64
#  19  valor258  1105 non-null   float64
#  20  valor261  10386 non-null  float64
#  21  valor263  1208 non-null   float64
#  22  valor264  1356 non-null   float64
#  23  valor288  2195 non-null   float64
#  24  valor295  1102 non-null   float64
#  25  valor297  2376 non-null   float64
# dtypes: float64(25), object(1)
# memory usage: 8.6+ MB
# nulos
# fecha           0
# valor009    40905
# valor010    24186
# valor033    10106
# valor088    24743
# valor134     2115
# valor183    10253
# valor184    42368
# valor191    43349
# valor210    41188
# valor211    10296
# e218           33
# valor219    42308
# valor248    41086
# valor252    42267
# valor253    42259
# valor254    30891
# valor255    10258
# valor257    41144
# valor258    42440
# valor261    33159
# valor263    42337
# valor264    42189
# valor288    41350
# valor295    42443
# valor297    41169
# dtype: int64

# %%
df1.head()
# Out:
#         fecha  valor009  valor010  valor033  valor088  valor134  valor183  \
# 0  1904-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 1  1904-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2  1904-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 3  1904-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 4  1904-01-05       NaN       NaN       NaN       NaN       NaN       NaN
#
#    valor184  valor191  valor210  ...  valor254  valor255  valor257  valor258  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
#
#    valor261  valor263  valor264  valor288  valor295  valor297
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 26 columns]

# %%
df1_copy['fecha'] = pd.to_datetime(df1_copy['fecha'])#formato fecha pandas
df1_copy.set_index('fecha',inplace=True)
datos_asuncion = df1_copy['e218']
datos_asuncion_interpolado = datos_asuncion.interpolate(limit = 35, method ='quadratic', limit_direction='both')
dataset = pd.DataFrame(datos_asuncion_interpolado)
dataset.columns = ['nivel']

# %%
# Encuentra los índices donde hay valores NaN
indices_nan = np.argwhere(np.isnan(datos_asuncion))

# Imprime los índices donde están los valores NaN
print("Índices con valores NaN:")
print(indices_nan)
# Out:
# Índices con valores NaN:
# [[21274]
#  [21457]
#  [21548]
#  [21549]
#  [39097]
#  [40775]
#  [40807]
#  [40808]
#  [40809]
#  [40815]
#  [41057]
#  [41066]
#  [41126]
#  [41132]
#  [41266]
#  [41273]
#  [41350]
#  [41370]
#  [41378]
#  [41379]
#  [41380]
#  [41393]
#  [41497]
#  [41528]
#  [41756]
#  [41768]
#  [41798]
#  [41812]
#  [42301]
#  [42302]
#  [42361]
#  [42365]
#  [42368]]

# %% [markdown]
# *   LSTM((Long Short-Term Memory))
# *   Arima
#
#
# *   Redes neuronales convolucionales recurrentes (CRNN)
# *  Redes neuronales de estado recurrente (RNN) vanilla

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True )
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'
print(os.getenv('TF_GPU_ALLOCATOR'))
# Out:
# cuda_malloc_async

# %%
dataset.head()
# Out:
#             nivel
# fecha
# 1904-01-01   5.12
# 1904-01-02   5.16
# 1904-01-03   5.09
# 1904-01-04   4.96
# 1904-01-05   4.90

# %%
datos_norm = dataset
#contiene numeros entre 0 y 1 normalizados de acuerdo a 53 semanas , 53 semanas la cantidad de semanas que tiene un año aproximadamente
#para analizar la estacionalidad o los patrones cíclicos en los datos.
datos_norm['week_cos'] =  np.cos(2 * np.pi * datos_norm.index.isocalendar().week / 53)
datos_norm['week_sin'] =  np.sin(2 * np.pi * datos_norm.index.isocalendar().week / 53)
#predecir valores futuros para los proximos 28 dias
horizonte = 28
# datos de los últimos 545 días para predecir los niveles de río para los próximos 28 días.
tamanio_ventana=545

cantidad_unidades=60
#muestras que se procesarán simultáneamente durante el entrenamiento del modelo
tamanio_batch=60
#probabilidad de que una neurona se desactive aleatoriamente durante el entrenamiento. Prevenir sobreajuste al 25%
dropout=0.250393
#caracteristicas para el entrenamiento
features_set=1
#anho inicial 1973
year_ini=73
arch='LSTM'#nombre del modelo
#Etiqueta descriptiva del modelo
modelo=arch+'_h'+str(horizonte)+'_w'+str(tamanio_ventana)+'_u'+str(cantidad_unidades)
modelo+='_d'+str(dropout)
modelo+='_f'+str(features_set)
modelo+='_y'+str(year_ini)

# %%
def preparar_datos(tamanio_ventana,horizonte, data):
    n_features=len(data.columns)
    x_train = np.zeros((len(data)-tamanio_ventana-horizonte+1,tamanio_ventana, n_features))
    y_train= np.zeros((len(data)-tamanio_ventana-horizonte+1, horizonte ))
    for i in range(tamanio_ventana, len(data)-horizonte +1):
        x_train[(i-tamanio_ventana), :, :] = data.iloc[(i-tamanio_ventana):(i), :]
        y_train[i-tamanio_ventana, :] = data['nivel'].iloc[(i):(i+horizonte)]
    return x_train,y_train

# %%
lista=[['nivel'],['nivel','week_cos','week_sin']]
seed=42

# %%
#modelo de aprendizaje automático de series temporales
#semilla aleatoria para determinismo
tf.random.set_seed(seed)
np.random.seed(seed)
datos_normm=datos_norm[lista[features_set]]
nfeatures=len(datos_normm.columns)
#01-01-1973-545 dias = 22-12-1972 fecha inicial
desde=(dt.datetime.strptime('19'+str(year_ini)+'-01-01', '%Y-%m-%d')- dt.timedelta(days=tamanio_ventana)).strftime('%Y/%m/%d')
desde_i=(dt.datetime.strptime('1905-01-01', '%Y-%m-%d')- dt.timedelta(days=tamanio_ventana)).strftime('%Y/%m/%d')
#subconjunto train
train = datos_normm.loc[desde:'2013-12-31'] #42 años
#muestra para ver
muestra14 = datos_norm.loc[desde_i:'1912-12-31']
muestra13 = datos_norm.loc[desde_i:'1922-12-31']
muestra12 = datos_norm.loc[desde_i:'1932-12-31']
muestra11 = datos_norm.loc[desde_i:'1942-12-31']
muestra10 = datos_norm.loc[desde_i:'1952-12-31']
muestra9 = datos_norm.loc[desde_i:'1962-12-31']
muestra8 = datos_norm.loc[desde_i:'1972-12-31']
muestra7 = datos_norm.loc[desde:'1982-12-31']
muestra1 = datos_norm.loc[desde:'1992-12-31']
muestra2 = datos_norm.loc[desde:'2002-12-31']
muestra3 = datos_norm.loc[desde:'2013-12-31']
muestra4 = datos_norm.loc[desde:'2023-03-21']
muestra5 = datos_norm.loc[desde:'2019-12-31']
muestra6 = datos_norm.loc[desde:'2016-12-31']
#tomando los indices del subconjunto
ix=train.index
trainScaler = MinMaxScaler(feature_range=(0, 1))#del sklearn
trainScaler.fit(train)#se normaliza el subconjunto entre 0 a 1
#transform(train) es un array Numpy y se aplica la normalizacion
#se crea un nuevo dataframe llamado trainScaled
trainScaled = pd.DataFrame(trainScaler.transform(train),columns=train.columns)
trainScaled.set_index(ix)
#Preparar los datos de entrenamiento con la funcion
x_train, y_train=preparar_datos(tamanio_ventana,horizonte, trainScaled)

#para el subconjunto validacion se toma la fecha inicial 01-01-2014
desde=(dt.datetime.strptime('2014-01-01', '%Y-%m-%d')- dt.timedelta(days=tamanio_ventana)).strftime('%Y/%m/%d')
#Subconjunto validacion mismo proceso anterior  al subconjunto entrenamiento
val = datos_normm.loc[desde:'2017-12-31'] # 4 años
ix=val.index
valScaler = MinMaxScaler(feature_range=(0, 1))
valScaler.fit(val)
valScaled = pd.DataFrame(valScaler.transform(val),columns=val.columns)
valScaled.set_index(ix)
#preprarar datos conjunto validacion
x_val, y_val=preparar_datos(tamanio_ventana,horizonte, valScaled)

# %%
train.head()
# Out:
#             nivel  week_cos  week_sin
# fecha
# 1971-07-06   1.73 -0.998244 -0.059241
# 1971-07-07   1.68 -0.998244 -0.059241
# 1971-07-08   1.64 -0.998244 -0.059241
# 1971-07-09   1.62 -0.998244 -0.059241
# 1971-07-10   1.58 -0.998244 -0.059241

# %%
datos_norm.tail()
# Out:
#             nivel  week_cos  week_sin
# fecha
# 2023-03-17   4.97  0.263587  0.964636
# 2023-03-18   5.07  0.263587  0.964636
# 2023-03-19   5.15  0.263587  0.964636
# 2023-03-20   5.21  0.147647   0.98904
# 2023-03-21   5.26  0.147647   0.98904

# %%
data1 = muestra14['nivel'][-2800:]
data2 = muestra13['nivel'][-3650:]
data3= muestra12['nivel'][-3650:]
data4= muestra11['nivel'][-2800:]
# Calcula el rango máximo y mínimo para todos los conjuntos de datos (excepto el límite inferior)
max_nivel = max(data1.max(), data2.max(), data3.max(),data4.max())
# Crea la figura y define la cuadrícula
fig = plt.figure(figsize=(15, 8))
gs = GridSpec(nrows=2, ncols=2)
# Diagrama del primer gráfico en el subplot superior izquierdo
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(data1)
ax1.grid(True)

# Diagrama del segundo gráfico en el subplot superior derecho
ax2 = fig.add_subplot(gs[0, 1])
ax2.plot(data2)
ax2.grid(True)


ax3 = fig.add_subplot(gs[1, 0])
ax3.plot(data3)
ax3.grid(True)

ax4 = fig.add_subplot(gs[1, 1])
ax4.plot(data4)
ax4.grid(True)

ax1.set_ylim(0, max_nivel)
ax2.set_ylim(-1, max_nivel)
ax3.set_ylim(0, max_nivel)
ax4.set_ylim(0, max_nivel)
# Ajusta el diseño y muestra la figura
plt.tight_layout()
plt.show()

# %%
data1 = muestra10['nivel'][-3650:]
data2 = muestra9['nivel'][-3650:]
data3= muestra8['nivel'][-3650:]
data4= muestra7['nivel'][-3650:]
# Calcula el rango máximo y mínimo para todos los conjuntos de datos (excepto el límite inferior)
max_nivel = max(data1.max(), data2.max(), data3.max(),data4.max())
# Crea la figura y define la cuadrícula
fig = plt.figure(figsize=(15, 8))
gs = GridSpec(nrows=2, ncols=2)
# Diagrama del primer gráfico en el subplot superior izquierdo
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(data1)
ax1.grid(True)

# Diagrama del segundo gráfico en el subplot superior derecho
ax2 = fig.add_subplot(gs[0, 1])
ax2.plot(data2)
ax2.grid(True)


ax3 = fig.add_subplot(gs[1, 0])
ax3.plot(data3)
ax3.grid(True)

ax4 = fig.add_subplot(gs[1, 1])
ax4.plot(data4)
ax4.grid(True)

ax1.set_ylim(0, max_nivel)
ax2.set_ylim(0, max_nivel)
ax3.set_ylim(-1, max_nivel)
ax4.set_ylim(0, max_nivel)
# Ajusta el diseño y muestra la figura
plt.tight_layout()
plt.show()

# %%
data1 = muestra1['nivel'][-3650:]
data2 = muestra2['nivel'][-3650:]
data3 = muestra3['nivel'][-3650:]
data4 = muestra4['nivel'][-3400:]

# Calcula el rango máximo y mínimo para todos los conjuntos de datos (excepto el límite inferior)
max_nivel = max(data1.max(), data2.max(), data3.max(), data4.max())

# Crea la figura y define la cuadrícula
fig = plt.figure(figsize=(15, 8))
gs = GridSpec(nrows=2, ncols=2)

# Diagrama del primer gráfico en el subplot superior izquierdo
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(data1)
ax1.grid(True)

# Diagrama del segundo gráfico en el subplot superior derecho
ax2 = fig.add_subplot(gs[0, 1])
ax2.plot(data2)

ax2.grid(True)

# Diagrama del tercer gráfico en el subplot inferior derecho
ax3 = fig.add_subplot(gs[1, 0])
ax3.plot(data3)

ax3.grid(True)

# Diagrama del cuarto gráfico en el subplot inferior derecho
ax4 = fig.add_subplot(gs[1, 1])
ax4.plot(data4)

ax4.grid(True)

# Ajusta el rango del eje y para todos los subplots, estableciendo -1 como límite inferior
ax1.set_ylim(0, max_nivel)
ax2.set_ylim(-1, max_nivel)
ax3.set_ylim(0, max_nivel)
ax4.set_ylim(-1, max_nivel)

# Ajusta el diseño y muestra la figura
plt.tight_layout()
plt.show()

# %%
data4 = muestra4['nivel'][-1095:]
data5 = muestra5['nivel'][-1095:]
data6 = muestra6['nivel'][-1095:]
# Crea la figura y define la cuadrícula
fig = plt.figure(figsize=(15, 8))
gs = GridSpec(nrows=2, ncols=2)

# Diagrama del primer gráfico en el subplot superior izquierdo
ax1 = fig.add_subplot(gs[1, 0])
ax1.plot(data4)
ax1.grid(True)

# Diagrama del segundo gráfico en el subplot superior derecho
ax2 = fig.add_subplot(gs[0, 1])
ax2.plot(data5)
ax2.grid(True)

ax3 = fig.add_subplot(gs[0, 0])
ax3.plot(data6)
ax3.grid(True)


# Ajusta el rango del eje y para todos los subplots, estableciendo -1 como límite inferior
ax1.set_ylim(-1, 8.5)
ax2.set_ylim(0, 8.5)
ax3.set_ylim(-1, 8.5)

# Ajusta el diseño y muestra la figura
plt.tight_layout()
plt.show()

# %%
train['nivel'][-3650:].plot()

# %%
#test de KPSS o ADF (dickey fuller)
from statsmodels.tsa.stattools import adfuller
X=train['nivel'].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -7.011606
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# El valor de esta estadística es -7.011647. Este valor es más negativo que los valores críticos en el nivel del 1%, 5% y 10%, lo que sugiere que podemos rechazar la hipótesis nula de que la serie tiene una raíz unitaria. En otras palabras, la serie es estacionaria.
#  rechazamos la hipótesis nula de no estacionariedad por p=0.
# Critical Values: Son los valores críticos para diferentes niveles de significancia (1%, 5% y 10%). Estos valores se utilizan para comparar con la estadística ADF. Como el valor de la estadística ADF es más negativo que los valores críticos, reforzando la idea de que la serie es estacionaria.

# %%
#definicion de la arquitectura RNN red neuronal recurrente con capa LSTM para capturar dependencias a largo plazo de una serie temporal
model=keras.Sequential()
model.add(tf.keras.layers.LSTM(cantidad_unidades, input_shape=(tamanio_ventana, nfeatures)))
#capa dropout (evita sobreajustes)
model.add(tf.keras.layers.Dropout(rate=dropout))
model.add(tf.keras.layers.Dense(horizonte))#genera predicciones del horizonte deseado

# %%
#funcion para ponderar , asigna pesos (mayor elementos iniciales)/(menor elementos posteriores)
def exponential_decay_weights(seq_length, decay_factor): #seq_legth dimension de la secuencia temporal , decay factor tasa de disminucion de peso
    weights = np.exp(-decay_factor * np.arange(seq_length))#cada elemento del vector  se calcula con el exp(-factor* ...)
    return weights / np.sum(weights) #retorna un vector weights de long seq_length np.sum suma el total de los pesos y normaliza para que el total sea 1

# %% [markdown]
# La función exponential_decay_weights es útil para aplicaciones de aprendizaje automático que involucran series temporales donde la información temprana puede ser más relevante.

# %%
# Esta función calcula el error cuadrático medio (MSE)
# ponderado a lo largo de la secuencia temporal, teniendo en cuenta la importancia decreciente de los elementos anteriores.
def multi_step_loss(y_true, y_pred): #tensores y_true , y_pred donde y_true (etiquetas) , y_pred valores predichos del modelo
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])
    seq_length = 28  # Length of the time series
    decay_factor = -0.05  # Controls the rate of decay
    weights = tf.constant(exponential_decay_weights(seq_length, decay_factor), dtype=tf.float32)#usamos la funcion anterior para los pesos
    squared_diff = tf.square(y_true - y_pred)#diferencia al cuadrado elemento a elemento entre (y_true - y_pred)
    weighted_squared_diff = tf.math.multiply(squared_diff, tf.expand_dims(weights, axis=-1))
    mse= tf.reduce_mean(weighted_squared_diff )#error cuadratico medio ponderado
    num_steps = 28  # Number of steps in each prediction
    adjusted_loss = mse / num_steps #ajuste de acuerdo al nro de pasos
    return adjusted_loss #error cuadratico medio

# %%
#configuracion del proceso de entrenamiento de la red neuronal
#model.compile(optimizer , loss , info adicional monitoreo del mse)
model.compile(optimizer=keras.optimizers.Adam(0.001), loss=multi_step_loss,metrics=[RootMeanSquaredError()])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60)                15360
#
#  dropout (Dropout)           (None, 60)                0
#
#  dense (Dense)               (None, 28)                1708
#
# =================================================================
# Total params: 17068 (66.67 KB)
# Trainable params: 17068 (66.67 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
start_time = time.time() #sirve para calculo de tiempo de ejecucion
#callback de detencion temprana , monitoriza val_loss y si en 10 epochs no mejora la perdida de validacion se detiene
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
# controla cuánto se actualizan los pesos del modelo en cada paso de entrenamiento.
# Un valor más alto permite un aprendizaje más rápido al principio,
#mientras que un valor más bajo permite un ajuste más fino en las etapas posteriores.
initial_learning_rate=0.0005
def lr_step_decay(epoch, lr): #ingresa epoca actual y lr actual
    drop = 0.5 #factor de decremento , baja el lr 0.5 con cada paso
    epochs_drop = 10#epocas que pasan entre cada decremento
    lr = initial_learning_rate * (drop ** (epoch // epochs_drop)) # se renueva el lr
    return lr
#Se crea un programador del ratio de aprendizaje para ajustar el ratio de aprendizaje durante el entrenamiento.
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lr_step_decay)
epocas=200
callbacks_list = [early_stopping,lr_scheduler ]#lista (callback, programador )
#se inicia el entrenamiento
#history contiene información sobre el proceso de entrenamiento, como la pérdida de entrenamiento y validación en cada época.
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=epocas, shuffle=False,batch_size=tamanio_batch, verbose=1, callbacks=[callbacks_list])
#se realiza la prediccion de x_val , las predicciones se escalan al valor original para luego ser comparadas o y_val
Y_prediction = valScaler.inverse_transform(np.hstack(((model.predict(x_val).reshape(-1, 1), np.zeros((np.size(y_val),nfeatures -1))))))[:, 0]

y_val_inv=valScaler.inverse_transform(np.hstack(((y_val.reshape(-1, 1), np.zeros((np.size(y_val),nfeatures -1))))))[:, 0]
#se calcula mse
mse=mean_squared_error( y_val_inv, Y_prediction)
#raiz cuadrado del mse
rmse=np.sqrt(mse)
#error maximo entre y_val_inv e y_prediction
maxError_=max_error(y_val_inv, Y_prediction)
#coeficiente de determinacion r cuadrado
#indica la proporción de la varianza en las etiquetas de validación
#que puede explicarse por el modelo. Un valor de R-cuadrado cercano a 1 indica un buen ajuste del modelo.
r2_=r2_score(y_val_inv, Y_prediction)
print( "MSE: " + str(mse)+" RMSE:" + str(rmse  ))
print( "MaxError: " + str(maxError_)+" R2:" + str(r2_  ))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time step : {elapsed_time:.6f} seconds")
# Out:
# Epoch 1/200
# 250/250 [==============================] - 8s 34ms/step - loss: 4.7902e-06 - root_mean_squared_error: 0.0613 - val_loss: 1.2034e-05 - val_root_mean_squared_error: 0.0971 - lr: 5.0000e-04
# Epoch 2/200
# 250/250 [==============================] - 5s 19ms/step - loss: 4.7272e-06 - root_mean_squared_error: 0.0609 - val_loss: 1.1936e-05 - val_root_mean_squared_error: 0.0967 - lr: 5.0000e-04
# Epoch 3/200
# 250/250 [==============================] - 5s 19ms/step - loss: 4.5593e-06 - root_mean_squared_error: 0.0598 - val_loss: 1.1877e-05 - val_root_mean_squared_error: 0.0965 - lr: 5.0000e-04
# Epoch 4/200
# 250/250 [==============================] - 5s 21ms/step - loss: 4.5179e-06 - root_mean_squared_error: 0.0595 - val_loss: 1.1760e-05 - val_root_mean_squared_error: 0.0960 - lr: 5.0000e-04
# Epoch 5/200
# 250/250 [==============================] - 5s 20ms/step - loss: 4.4505e-06 - root_mean_squared_error: 0.0591 - val_loss: 1.1719e-05 - val_root_mean_squared_error: 0.0959 - lr: 5.0000e-04
# Epoch 6/200
# 250/250 [==============================] - 6s 24ms/step - loss: 4.4326e-06 - root_mean_squared_error: 0.0590 - val_loss: 1.1925e-05 - val_root_mean_squared_error: 0.0967 - lr: 5.0000e-04
# Epoch 7/200
# 250/250 [==============================] - 5s 18ms/step - loss: 4.3494e-06 - root_mean_squared_error: 0.0584 - val_loss: 1.1694e-05 - val_root_mean_squared_error: 0.0958 - lr: 5.0000e-04
# Epoch 8/200
# 250/250 [==============================] - 5s 18ms/step - loss: 4.3676e-06 - root_mean_squared_error: 0.0585 - val_loss: 1.1710e-05 - val_root_mean_squared_error: 0.0958 - lr: 5.0000e-04
# Epoch 9/200
# 250/250 [==============================] - 5s 22ms/step - loss: 4.2872e-06 - root_mean_squared_error: 0.0580 - val_loss: 1.1559e-05 - val_root_mean_squared_error: 0.0952 - lr: 5.0000e-04
# Epoch 10/200
# 250/250 [==============================] - 5s 19ms/step - loss: 4.2575e-06 - root_mean_squared_error: 0.0578 - val_loss: 1.1631e-05 - val_root_mean_squared_error: 0.0955 - lr: 5.0000e-04
# Epoch 11/200
# 250/250 [==============================] - 5s 20ms/step - loss: 4.1339e-06 - root_mean_squared_error: 0.0569 - val_loss: 1.1382e-05 - val_root_mean_squared_error: 0.0945 - lr: 2.5000e-04
# Epoch 12/200
# 250/250 [==============================] - 5s 20ms/step - loss: 4.0820e-06 - root_mean_squared_error: 0.0566 - val_loss: 1.1454e-05 - val_root_mean_squared_error: 0.0948 - lr: 2.5000e-04
# Epoch 13/200
# 250/250 [==============================] - 4s 18ms/step - loss: 4.0664e-06 - root_mean_squared_error: 0.0565 - val_loss: 1.1318e-05 - val_root_mean_squared_error: 0.0942 - lr: 2.5000e-04
# Epoch 14/200
# 250/250 [==============================] - 6s 22ms/step - loss: 4.0772e-06 - root_mean_squared_error: 0.0565 - val_loss: 1.1359e-05 - val_root_mean_squared_error: 0.0944 - lr: 2.5000e-04
# Epoch 15/200
# 250/250 [==============================] - 5s 18ms/step - loss: 4.0742e-06 - root_mean_squared_error: 0.0565 - val_loss: 1.1267e-05 - val_root_mean_squared_error: 0.0940 - lr: 2.5000e-04
# Epoch 16/200
# 250/250 [==============================] - 5s 18ms/step - loss: 4.0290e-06 - root_mean_squared_error: 0.0562 - val_loss: 1.1362e-05 - val_root_mean_squared_error: 0.0944 - lr: 2.5000e-04
# Epoch 17/200
# 250/250 [==============================] - 5s 22ms/step - loss: 4.0398e-06 - root_mean_squared_error: 0.0563 - val_loss: 1.1229e-05 - val_root_mean_squared_error: 0.0938 - lr: 2.5000e-04
# Epoch 18/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.9812e-06 - root_mean_squared_error: 0.0559 - val_loss: 1.1159e-05 - val_root_mean_squared_error: 0.0935 - lr: 2.5000e-04
# Epoch 19/200
# 250/250 [==============================] - 9s 34ms/step - loss: 3.9973e-06 - root_mean_squared_error: 0.0560 - val_loss: 1.1294e-05 - val_root_mean_squared_error: 0.0941 - lr: 2.5000e-04
# Epoch 20/200
# 250/250 [==============================] - 5s 18ms/step - loss: 4.0007e-06 - root_mean_squared_error: 0.0560 - val_loss: 1.1173e-05 - val_root_mean_squared_error: 0.0936 - lr: 2.5000e-04
# Epoch 21/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.9558e-06 - root_mean_squared_error: 0.0557 - val_loss: 1.0907e-05 - val_root_mean_squared_error: 0.0925 - lr: 1.2500e-04
# Epoch 22/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.9398e-06 - root_mean_squared_error: 0.0556 - val_loss: 1.0860e-05 - val_root_mean_squared_error: 0.0923 - lr: 1.2500e-04
# Epoch 23/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.9278e-06 - root_mean_squared_error: 0.0555 - val_loss: 1.0873e-05 - val_root_mean_squared_error: 0.0923 - lr: 1.2500e-04
# Epoch 24/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.9293e-06 - root_mean_squared_error: 0.0555 - val_loss: 1.0856e-05 - val_root_mean_squared_error: 0.0923 - lr: 1.2500e-04
# Epoch 25/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8870e-06 - root_mean_squared_error: 0.0552 - val_loss: 1.0808e-05 - val_root_mean_squared_error: 0.0921 - lr: 1.2500e-04
# Epoch 26/200
# 250/250 [==============================] - 4s 18ms/step - loss: 3.9124e-06 - root_mean_squared_error: 0.0554 - val_loss: 1.0845e-05 - val_root_mean_squared_error: 0.0922 - lr: 1.2500e-04
# Epoch 27/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.9030e-06 - root_mean_squared_error: 0.0553 - val_loss: 1.0790e-05 - val_root_mean_squared_error: 0.0920 - lr: 1.2500e-04
# Epoch 28/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.9109e-06 - root_mean_squared_error: 0.0554 - val_loss: 1.0810e-05 - val_root_mean_squared_error: 0.0921 - lr: 1.2500e-04
# Epoch 29/200
# 250/250 [==============================] - 4s 18ms/step - loss: 3.8988e-06 - root_mean_squared_error: 0.0553 - val_loss: 1.0785e-05 - val_root_mean_squared_error: 0.0920 - lr: 1.2500e-04
# Epoch 30/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.8756e-06 - root_mean_squared_error: 0.0551 - val_loss: 1.0827e-05 - val_root_mean_squared_error: 0.0921 - lr: 1.2500e-04
# Epoch 31/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.9032e-06 - root_mean_squared_error: 0.0553 - val_loss: 1.0522e-05 - val_root_mean_squared_error: 0.0908 - lr: 6.2500e-05
# Epoch 32/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8932e-06 - root_mean_squared_error: 0.0552 - val_loss: 1.0469e-05 - val_root_mean_squared_error: 0.0906 - lr: 6.2500e-05
# Epoch 33/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8585e-06 - root_mean_squared_error: 0.0550 - val_loss: 1.0457e-05 - val_root_mean_squared_error: 0.0905 - lr: 6.2500e-05
# Epoch 34/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8883e-06 - root_mean_squared_error: 0.0552 - val_loss: 1.0473e-05 - val_root_mean_squared_error: 0.0906 - lr: 6.2500e-05
# Epoch 35/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.8655e-06 - root_mean_squared_error: 0.0551 - val_loss: 1.0448e-05 - val_root_mean_squared_error: 0.0905 - lr: 6.2500e-05
# Epoch 36/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8844e-06 - root_mean_squared_error: 0.0552 - val_loss: 1.0439e-05 - val_root_mean_squared_error: 0.0905 - lr: 6.2500e-05
# Epoch 37/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8911e-06 - root_mean_squared_error: 0.0552 - val_loss: 1.0427e-05 - val_root_mean_squared_error: 0.0904 - lr: 6.2500e-05
# Epoch 38/200
# 250/250 [==============================] - 6s 25ms/step - loss: 3.8798e-06 - root_mean_squared_error: 0.0552 - val_loss: 1.0408e-05 - val_root_mean_squared_error: 0.0903 - lr: 6.2500e-05
# Epoch 39/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8524e-06 - root_mean_squared_error: 0.0550 - val_loss: 1.0404e-05 - val_root_mean_squared_error: 0.0903 - lr: 6.2500e-05
# Epoch 40/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.8426e-06 - root_mean_squared_error: 0.0549 - val_loss: 1.0394e-05 - val_root_mean_squared_error: 0.0903 - lr: 6.2500e-05
# Epoch 41/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8803e-06 - root_mean_squared_error: 0.0552 - val_loss: 1.0151e-05 - val_root_mean_squared_error: 0.0892 - lr: 3.1250e-05
# Epoch 42/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8800e-06 - root_mean_squared_error: 0.0552 - val_loss: 1.0127e-05 - val_root_mean_squared_error: 0.0891 - lr: 3.1250e-05
# Epoch 43/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8524e-06 - root_mean_squared_error: 0.0550 - val_loss: 1.0117e-05 - val_root_mean_squared_error: 0.0891 - lr: 3.1250e-05
# Epoch 44/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8326e-06 - root_mean_squared_error: 0.0548 - val_loss: 1.0127e-05 - val_root_mean_squared_error: 0.0891 - lr: 3.1250e-05
# Epoch 45/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8765e-06 - root_mean_squared_error: 0.0551 - val_loss: 1.0115e-05 - val_root_mean_squared_error: 0.0891 - lr: 3.1250e-05
# Epoch 46/200
# 250/250 [==============================] - 6s 24ms/step - loss: 3.8396e-06 - root_mean_squared_error: 0.0549 - val_loss: 1.0117e-05 - val_root_mean_squared_error: 0.0891 - lr: 3.1250e-05
# Epoch 47/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8714e-06 - root_mean_squared_error: 0.0551 - val_loss: 1.0112e-05 - val_root_mean_squared_error: 0.0890 - lr: 3.1250e-05
# Epoch 48/200
# 250/250 [==============================] - 6s 24ms/step - loss: 3.8607e-06 - root_mean_squared_error: 0.0550 - val_loss: 1.0105e-05 - val_root_mean_squared_error: 0.0890 - lr: 3.1250e-05
# Epoch 49/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8666e-06 - root_mean_squared_error: 0.0551 - val_loss: 1.0104e-05 - val_root_mean_squared_error: 0.0890 - lr: 3.1250e-05
# Epoch 50/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8457e-06 - root_mean_squared_error: 0.0549 - val_loss: 1.0097e-05 - val_root_mean_squared_error: 0.0890 - lr: 3.1250e-05
# Epoch 51/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8719e-06 - root_mean_squared_error: 0.0551 - val_loss: 9.9756e-06 - val_root_mean_squared_error: 0.0884 - lr: 1.5625e-05
# Epoch 52/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8546e-06 - root_mean_squared_error: 0.0550 - val_loss: 9.9803e-06 - val_root_mean_squared_error: 0.0885 - lr: 1.5625e-05
# Epoch 53/200
# 250/250 [==============================] - 7s 27ms/step - loss: 3.8580e-06 - root_mean_squared_error: 0.0550 - val_loss: 9.9667e-06 - val_root_mean_squared_error: 0.0884 - lr: 1.5625e-05
# Epoch 54/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8416e-06 - root_mean_squared_error: 0.0549 - val_loss: 9.9633e-06 - val_root_mean_squared_error: 0.0884 - lr: 1.5625e-05
# Epoch 55/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8238e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.9660e-06 - val_root_mean_squared_error: 0.0884 - lr: 1.5625e-05
# Epoch 56/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8471e-06 - root_mean_squared_error: 0.0549 - val_loss: 9.9710e-06 - val_root_mean_squared_error: 0.0884 - lr: 1.5625e-05
# Epoch 57/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8122e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.9595e-06 - val_root_mean_squared_error: 0.0884 - lr: 1.5625e-05
# Epoch 58/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.8186e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.9623e-06 - val_root_mean_squared_error: 0.0884 - lr: 1.5625e-05
# Epoch 59/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8531e-06 - root_mean_squared_error: 0.0550 - val_loss: 9.9587e-06 - val_root_mean_squared_error: 0.0884 - lr: 1.5625e-05
# Epoch 60/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.8270e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.9586e-06 - val_root_mean_squared_error: 0.0884 - lr: 1.5625e-05
# Epoch 61/200
# 250/250 [==============================] - 6s 22ms/step - loss: 3.8529e-06 - root_mean_squared_error: 0.0550 - val_loss: 9.9292e-06 - val_root_mean_squared_error: 0.0882 - lr: 7.8125e-06
# Epoch 62/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.8263e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.9220e-06 - val_root_mean_squared_error: 0.0882 - lr: 7.8125e-06
# Epoch 63/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8082e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.9213e-06 - val_root_mean_squared_error: 0.0882 - lr: 7.8125e-06
# Epoch 64/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8066e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.9185e-06 - val_root_mean_squared_error: 0.0882 - lr: 7.8125e-06
# Epoch 65/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.8381e-06 - root_mean_squared_error: 0.0549 - val_loss: 9.9159e-06 - val_root_mean_squared_error: 0.0882 - lr: 7.8125e-06
# Epoch 66/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.8334e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.9147e-06 - val_root_mean_squared_error: 0.0882 - lr: 7.8125e-06
# Epoch 67/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8107e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.9175e-06 - val_root_mean_squared_error: 0.0882 - lr: 7.8125e-06
# Epoch 68/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.8288e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.9159e-06 - val_root_mean_squared_error: 0.0882 - lr: 7.8125e-06
# Epoch 69/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.8217e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.9137e-06 - val_root_mean_squared_error: 0.0882 - lr: 7.8125e-06
# Epoch 70/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.8234e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.9129e-06 - val_root_mean_squared_error: 0.0882 - lr: 7.8125e-06
# Epoch 71/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8485e-06 - root_mean_squared_error: 0.0549 - val_loss: 9.9079e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.9063e-06
# Epoch 72/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8269e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.9043e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.9063e-06
# Epoch 73/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.8054e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.9029e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.9063e-06
# Epoch 74/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8090e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.9008e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.9063e-06
# Epoch 75/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8024e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.9006e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.9063e-06
# Epoch 76/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8230e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8998e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.9063e-06
# Epoch 77/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8075e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.9004e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.9063e-06
# Epoch 78/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.8172e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8989e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.9063e-06
# Epoch 79/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8058e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8986e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.9063e-06
# Epoch 80/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8214e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8988e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.9063e-06
# Epoch 81/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.8140e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8976e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.9531e-06
# Epoch 82/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8130e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8964e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.9531e-06
# Epoch 83/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8207e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8953e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.9531e-06
# Epoch 84/200
# 250/250 [==============================] - 5s 18ms/step - loss: 3.8042e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8946e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.9531e-06
# Epoch 85/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8316e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8951e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.9531e-06
# Epoch 86/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8109e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8939e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.9531e-06
# Epoch 87/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8167e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8932e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.9531e-06
# Epoch 88/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.7955e-06 - root_mean_squared_error: 0.0545 - val_loss: 9.8936e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.9531e-06
# Epoch 89/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8048e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8935e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.9531e-06
# Epoch 90/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8318e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8935e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.9531e-06
# Epoch 91/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8148e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8932e-06 - val_root_mean_squared_error: 0.0881 - lr: 9.7656e-07
# Epoch 92/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8066e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8933e-06 - val_root_mean_squared_error: 0.0881 - lr: 9.7656e-07
# Epoch 93/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8086e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8928e-06 - val_root_mean_squared_error: 0.0881 - lr: 9.7656e-07
# Epoch 94/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8036e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8926e-06 - val_root_mean_squared_error: 0.0881 - lr: 9.7656e-07
# Epoch 95/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8287e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8922e-06 - val_root_mean_squared_error: 0.0881 - lr: 9.7656e-07
# Epoch 96/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8041e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8922e-06 - val_root_mean_squared_error: 0.0881 - lr: 9.7656e-07
# Epoch 97/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8081e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8913e-06 - val_root_mean_squared_error: 0.0881 - lr: 9.7656e-07
# Epoch 98/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8108e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8908e-06 - val_root_mean_squared_error: 0.0881 - lr: 9.7656e-07
# Epoch 99/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.7863e-06 - root_mean_squared_error: 0.0545 - val_loss: 9.8906e-06 - val_root_mean_squared_error: 0.0881 - lr: 9.7656e-07
# Epoch 100/200
# 250/250 [==============================] - 6s 26ms/step - loss: 3.8143e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8907e-06 - val_root_mean_squared_error: 0.0881 - lr: 9.7656e-07
# Epoch 101/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8085e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8906e-06 - val_root_mean_squared_error: 0.0881 - lr: 4.8828e-07
# Epoch 102/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8228e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8908e-06 - val_root_mean_squared_error: 0.0881 - lr: 4.8828e-07
# Epoch 103/200
# 250/250 [==============================] - 6s 24ms/step - loss: 3.8107e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8907e-06 - val_root_mean_squared_error: 0.0881 - lr: 4.8828e-07
# Epoch 104/200
# 250/250 [==============================] - 6s 24ms/step - loss: 3.8083e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8905e-06 - val_root_mean_squared_error: 0.0881 - lr: 4.8828e-07
# Epoch 105/200
# 250/250 [==============================] - 6s 24ms/step - loss: 3.8040e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8904e-06 - val_root_mean_squared_error: 0.0881 - lr: 4.8828e-07
# Epoch 106/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8148e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8902e-06 - val_root_mean_squared_error: 0.0881 - lr: 4.8828e-07
# Epoch 107/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.7886e-06 - root_mean_squared_error: 0.0545 - val_loss: 9.8902e-06 - val_root_mean_squared_error: 0.0881 - lr: 4.8828e-07
# Epoch 108/200
# 250/250 [==============================] - 6s 24ms/step - loss: 3.8175e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8900e-06 - val_root_mean_squared_error: 0.0881 - lr: 4.8828e-07
# Epoch 109/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8003e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8899e-06 - val_root_mean_squared_error: 0.0881 - lr: 4.8828e-07
# Epoch 110/200
# 250/250 [==============================] - 7s 28ms/step - loss: 3.8097e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8897e-06 - val_root_mean_squared_error: 0.0881 - lr: 4.8828e-07
# Epoch 111/200
# 250/250 [==============================] - 6s 26ms/step - loss: 3.8135e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8897e-06 - val_root_mean_squared_error: 0.0881 - lr: 2.4414e-07
# Epoch 112/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8336e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8896e-06 - val_root_mean_squared_error: 0.0881 - lr: 2.4414e-07
# Epoch 113/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.7955e-06 - root_mean_squared_error: 0.0545 - val_loss: 9.8896e-06 - val_root_mean_squared_error: 0.0881 - lr: 2.4414e-07
# Epoch 114/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8178e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8895e-06 - val_root_mean_squared_error: 0.0881 - lr: 2.4414e-07
# Epoch 115/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8300e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8895e-06 - val_root_mean_squared_error: 0.0881 - lr: 2.4414e-07
# Epoch 116/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8061e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8895e-06 - val_root_mean_squared_error: 0.0881 - lr: 2.4414e-07
# Epoch 117/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.7942e-06 - root_mean_squared_error: 0.0545 - val_loss: 9.8894e-06 - val_root_mean_squared_error: 0.0881 - lr: 2.4414e-07
# Epoch 118/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8327e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8894e-06 - val_root_mean_squared_error: 0.0881 - lr: 2.4414e-07
# Epoch 119/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8166e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8893e-06 - val_root_mean_squared_error: 0.0881 - lr: 2.4414e-07
# Epoch 120/200
# 250/250 [==============================] - 6s 22ms/step - loss: 3.8120e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8891e-06 - val_root_mean_squared_error: 0.0881 - lr: 2.4414e-07
# Epoch 121/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.7952e-06 - root_mean_squared_error: 0.0545 - val_loss: 9.8892e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.2207e-07
# Epoch 122/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8159e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8892e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.2207e-07
# Epoch 123/200
# 250/250 [==============================] - 6s 22ms/step - loss: 3.8155e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8892e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.2207e-07
# Epoch 124/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8235e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8891e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.2207e-07
# Epoch 125/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8009e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8891e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.2207e-07
# Epoch 126/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.8078e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8891e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.2207e-07
# Epoch 127/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.7910e-06 - root_mean_squared_error: 0.0545 - val_loss: 9.8891e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.2207e-07
# Epoch 128/200
# 250/250 [==============================] - 6s 24ms/step - loss: 3.8187e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8891e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.2207e-07
# Epoch 129/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.7949e-06 - root_mean_squared_error: 0.0545 - val_loss: 9.8890e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.2207e-07
# Epoch 130/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8463e-06 - root_mean_squared_error: 0.0549 - val_loss: 9.8890e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.2207e-07
# Epoch 131/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.7957e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8890e-06 - val_root_mean_squared_error: 0.0881 - lr: 6.1035e-08
# Epoch 132/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8392e-06 - root_mean_squared_error: 0.0549 - val_loss: 9.8890e-06 - val_root_mean_squared_error: 0.0881 - lr: 6.1035e-08
# Epoch 133/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8097e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 6.1035e-08
# Epoch 134/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8379e-06 - root_mean_squared_error: 0.0549 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 6.1035e-08
# Epoch 135/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8082e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 6.1035e-08
# Epoch 136/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.7997e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 6.1035e-08
# Epoch 137/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8083e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 6.1035e-08
# Epoch 138/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8356e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 6.1035e-08
# Epoch 139/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8215e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 6.1035e-08
# Epoch 140/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8158e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 6.1035e-08
# Epoch 141/200
# 250/250 [==============================] - 6s 25ms/step - loss: 3.8238e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.0518e-08
# Epoch 142/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8097e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.0518e-08
# Epoch 143/200
# 250/250 [==============================] - 9s 35ms/step - loss: 3.7725e-06 - root_mean_squared_error: 0.0544 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.0518e-08
# Epoch 144/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.7706e-06 - root_mean_squared_error: 0.0544 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.0518e-08
# Epoch 145/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.7956e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.0518e-08
# Epoch 146/200
# 250/250 [==============================] - 6s 24ms/step - loss: 3.8017e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.0518e-08
# Epoch 147/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8320e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8889e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.0518e-08
# Epoch 148/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8077e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.0518e-08
# Epoch 149/200
# 250/250 [==============================] - 5s 22ms/step - loss: 3.8179e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.0518e-08
# Epoch 150/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8235e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 3.0518e-08
# Epoch 151/200
# 250/250 [==============================] - 6s 25ms/step - loss: 3.8107e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.5259e-08
# Epoch 152/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8052e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.5259e-08
# Epoch 153/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8406e-06 - root_mean_squared_error: 0.0549 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.5259e-08
# Epoch 154/200
# 250/250 [==============================] - 5s 21ms/step - loss: 3.8101e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.5259e-08
# Epoch 155/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.8203e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.5259e-08
# Epoch 156/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8146e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.5259e-08
# Epoch 157/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8045e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.5259e-08
# Epoch 158/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8210e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.5259e-08
# Epoch 159/200
# 250/250 [==============================] - 6s 22ms/step - loss: 3.8175e-06 - root_mean_squared_error: 0.0547 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.5259e-08
# Epoch 160/200
# 250/250 [==============================] - 5s 19ms/step - loss: 3.8241e-06 - root_mean_squared_error: 0.0548 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 1.5259e-08
# Epoch 161/200
# 250/250 [==============================] - 6s 23ms/step - loss: 3.8060e-06 - root_mean_squared_error: 0.0546 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 7.6294e-09
# Epoch 162/200
# 250/250 [==============================] - 5s 20ms/step - loss: 3.7924e-06 - root_mean_squared_error: 0.0545 - val_loss: 9.8888e-06 - val_root_mean_squared_error: 0.0881 - lr: 7.6294e-09
# 45/45 [==============================] - 1s 11ms/step
# MSE: 0.4222539114294546 RMSE:0.6498106735268778
# MaxError: 3.684512725472451 R2:0.8494621475949798
# Time step : 863.519723 seconds

# %%
import seaborn as sns #libreria de matplotlib crea visualizaciones esteticas
from matplotlib.ticker import FormatStrFormatter#formatear las etiquetas de los ejes en los gráficos, permitiendo especificar un formato de cadena para los valores.
import matplotlib.dates as dates #Este módulo proporciona funciones y clases para trabajar con datos temporales en gráficos de matplotlib
from matplotlib import dates as mdates#se puede utilizar para acceder a funciones y clases relacionadas con fechas dentro de matplotlib

# %%
df=val[['nivel']][ tamanio_ventana:]
# se crea una figura f y el eje ax
f, ax = plt.subplots(figsize=(15,5))
#graficos de lineas con datos de df y eje ax
sns.lineplot(data =df,ax=ax)
#Formato de fechas
#objeto localizador coloca marcas menores cada 3 meses
fmt_month = mdates.MonthLocator(interval=3)
# Minor ticks every year.
#marcas cada anho
fmt_year = mdates.YearLocator()

ax.xaxis.set_minor_locator(fmt_month)
# '%b' to get the names of the month Muestra los meses como Ene, Feb ..
ax.xaxis.set_minor_formatter(mdates.DateFormatter('%b'))
ax.xaxis.set_major_locator(fmt_year)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

# fontsize for month labels
ax.tick_params(labelsize=15, which='both') #tamanho de fuente de las etiquetas de marcas
    # create a second x-axis beneath the first x-axis to show the year in YYYY format
    #el eje se coloca por debajo al principal
sec_xaxis = ax.secondary_xaxis(-0.1)
sec_xaxis.xaxis.set_major_locator(fmt_year)
sec_xaxis.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

    # Hide the second x-axis spines and ticks
sec_xaxis.spines['bottom'].set_visible(False)
sec_xaxis.tick_params(length=0, labelsize=15)

ax.set_ylabel('Nivel Asunción (M)')
ax.set_xlabel('')

ax.set_xlim(df.index[0],df.index[-1])
j=0
mse=[]
maxe=[]
t=[]
    #El bucle itera sobre los valores predichos (Y_prediction) con un paso de horizonte.
for i in range(0, len(Y_prediction),horizonte):
  if(j%5==0 and (j+horizonte)<len(df)): #si j es divisible por 5 calcula mse , maxErr de
        #los valores reales de df.nivel[j:(j+horizonte)]) y valores predichos Y_prediction[i:i+horizonte]
    mse.append(mean_squared_error(np.array(df.nivel[j:(j+horizonte)]), Y_prediction[i:i+horizonte]))
    maxe.append(max_error(np.array(df.nivel[j:(j+horizonte)]), Y_prediction[i:i+horizonte]))
    t.append(df.index[j])

    plt.plot(df.index[j:(j+horizonte)], Y_prediction[i:i+horizonte], color='red')
  j=j+1

plt.show()

# %% [markdown]
# Las líneas rojas proporcionan una estimación de cómo el modelo espera que cambie el nivel del río en el futuro.
# La pendiente de las líneas rojas indica la tendencia pronosticada en el nivel del río (aumento, disminución o estabilidad).
# El modelo puede tener dificultades para predecir eventos extremos, como inundaciones repentinas o sequías severas.
# El modelo funciona para horizontes de prediccion cortos

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['train','val'], loc='upper right')
plt.show()

# %% [markdown]
#   El gráfico muestra que el MSE del modelo disminuye tanto en los datos de entrenamiento como en los datos de validación a medida que avanza el entrenamiento. Esto indica que el modelo está aprendiendo efectivamente a predecir el nivel del río.
# Se observa un posible problema de sobreajuste en las primeras épocas de entrenamiento.

# %% [markdown]
# # **Tomando el rango de temporalidad 2018 a 2022 para el test**
# con x_test , y_test

# %%
lista=[['nivel'],['nivel','week_cos','week_sin']]
seed=42
#semilla aleatoria para determinismo
tf.random.set_seed(seed)
np.random.seed(seed)
datos_normm=datos_norm[lista[features_set]]
nfeatures=len(datos_normm.columns)
#01-01-1973-545 dias = 22-12-1972 fecha inicial
desde=(dt.datetime.strptime('19'+str(year_ini)+'-01-01', '%Y-%m-%d')- dt.timedelta(days=tamanio_ventana)).strftime('%Y/%m/%d')
#subconjunto train  22-12-1972 a 31-12-2013
train = datos_normm.loc[desde:'2017-12-31']
#tomando los indices del subconjunto
ix=train.index
trainScaler = MinMaxScaler(feature_range=(0, 1))#del sklearn
trainScaler.fit(train)#se normaliza el subconjunto entre 0 a 1
#transform(train) es un array Numpy y se aplica la normalizacion
#se crea un nuevo dataframe llamado trainScaled
trainScaled = pd.DataFrame(trainScaler.transform(train),columns=train.columns)
trainScaled.set_index(ix)
#Preparar los datos de entrenamiento con la funcion
x_train, y_train=preparar_datos(tamanio_ventana,horizonte, trainScaled)

#para el subconjunto TEST se toma la fecha inicial 01-01-2018
desde=(dt.datetime.strptime('2018-01-01', '%Y-%m-%d')- dt.timedelta(days=tamanio_ventana)).strftime('%Y/%m/%d')
#Subconjunto validacion mismo proceso anterior  al subconjunto entrenamiento
test = datos_normm.loc[desde:'2022-12-31'] # 4 años para el conjunto test
ix=test.index
testScaler = MinMaxScaler(feature_range=(0, 1))
testScaler.fit(test)##??????????????
testScaled = pd.DataFrame(testScaler.transform(test),columns=test.columns)
testScaled.set_index(ix)
#preprarar datos conjunto validacion
x_test, y_test=preparar_datos(tamanio_ventana,horizonte, testScaled)

# %%
#definicion de la arquitectura RNN red neuronal recurrente con capa LSTM para capturar dependencias a largo plazo de una serie temporal
model=keras.Sequential()
model.add(tf.keras.layers.LSTM(cantidad_unidades, input_shape=(tamanio_ventana, nfeatures)))
#capa dropout (evita sobreajustes)
model.add(tf.keras.layers.Dropout(rate=dropout))
model.add(tf.keras.layers.Dense(horizonte))#genera predicciones del horizonte deseado
model.compile(optimizer=keras.optimizers.Adam(0.001), loss='mean_absolute_error',metrics=[RootMeanSquaredError()])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 60)                15360
#
#  dropout_1 (Dropout)         (None, 60)                0
#
#  dense_1 (Dense)             (None, 28)                1708
#
# =================================================================
# Total params: 17068 (66.67 KB)
# Trainable params: 17068 (66.67 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
# controla cuánto se actualizan los pesos del modelo en cada paso de entrenamiento.
# Un valor más alto permite un aprendizaje más rápido al principio,
#mientras que un valor más bajo permite un ajuste más fino en las etapas posteriores.
initial_learning_rate=0.0005
def lr_step_decay(epoch, lr): #ingresa epoca actual y lr actual
    drop = 0.5 #factor de decremento , baja el lr 0.5 con cada paso
    epochs_drop = 10#epocas que pasan entre cada decremento
    lr = initial_learning_rate * (drop ** (epoch // epochs_drop)) # se renueva el lr
    return lr
#Se crea un programador del ratio de aprendizaje para ajustar el ratio de aprendizaje durante el entrenamiento.
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lr_step_decay)
epocas=200
callbacks_list = [early_stopping,lr_scheduler ]#lista (callback, programador )
#se inicia el entrenamiento
#history contiene información sobre el proceso de entrenamiento, como la pérdida de entrenamiento y validación en cada época.
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=epocas, shuffle=False,batch_size=tamanio_batch, verbose=1, callbacks=[callbacks_list])
# Out:
# Epoch 1/200
# 274/274 [==============================] - 8s 24ms/step - loss: 0.1420 - root_mean_squared_error: 0.1907 - val_loss: 0.0995 - val_root_mean_squared_error: 0.1348 - lr: 5.0000e-04
# Epoch 2/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0837 - root_mean_squared_error: 0.1100 - val_loss: 0.0824 - val_root_mean_squared_error: 0.1144 - lr: 5.0000e-04
# Epoch 3/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0706 - root_mean_squared_error: 0.0933 - val_loss: 0.0746 - val_root_mean_squared_error: 0.1046 - lr: 5.0000e-04
# Epoch 4/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0636 - root_mean_squared_error: 0.0846 - val_loss: 0.0693 - val_root_mean_squared_error: 0.0979 - lr: 5.0000e-04
# Epoch 5/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0591 - root_mean_squared_error: 0.0793 - val_loss: 0.0664 - val_root_mean_squared_error: 0.0949 - lr: 5.0000e-04
# Epoch 6/200
# 274/274 [==============================] - 6s 20ms/step - loss: 0.0558 - root_mean_squared_error: 0.0753 - val_loss: 0.0663 - val_root_mean_squared_error: 0.0947 - lr: 5.0000e-04
# Epoch 7/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0537 - root_mean_squared_error: 0.0728 - val_loss: 0.0631 - val_root_mean_squared_error: 0.0915 - lr: 5.0000e-04
# Epoch 8/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0517 - root_mean_squared_error: 0.0706 - val_loss: 0.0610 - val_root_mean_squared_error: 0.0891 - lr: 5.0000e-04
# Epoch 9/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0499 - root_mean_squared_error: 0.0684 - val_loss: 0.0611 - val_root_mean_squared_error: 0.0894 - lr: 5.0000e-04
# Epoch 10/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0488 - root_mean_squared_error: 0.0672 - val_loss: 0.0590 - val_root_mean_squared_error: 0.0872 - lr: 5.0000e-04
# Epoch 11/200
# 274/274 [==============================] - 5s 18ms/step - loss: 0.0469 - root_mean_squared_error: 0.0652 - val_loss: 0.0576 - val_root_mean_squared_error: 0.0852 - lr: 2.5000e-04
# Epoch 12/200
# 274/274 [==============================] - 6s 20ms/step - loss: 0.0466 - root_mean_squared_error: 0.0648 - val_loss: 0.0568 - val_root_mean_squared_error: 0.0847 - lr: 2.5000e-04
# Epoch 13/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0459 - root_mean_squared_error: 0.0642 - val_loss: 0.0566 - val_root_mean_squared_error: 0.0845 - lr: 2.5000e-04
# Epoch 14/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0456 - root_mean_squared_error: 0.0638 - val_loss: 0.0561 - val_root_mean_squared_error: 0.0841 - lr: 2.5000e-04
# Epoch 15/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0450 - root_mean_squared_error: 0.0630 - val_loss: 0.0556 - val_root_mean_squared_error: 0.0837 - lr: 2.5000e-04
# Epoch 16/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0446 - root_mean_squared_error: 0.0628 - val_loss: 0.0554 - val_root_mean_squared_error: 0.0834 - lr: 2.5000e-04
# Epoch 17/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0442 - root_mean_squared_error: 0.0622 - val_loss: 0.0552 - val_root_mean_squared_error: 0.0833 - lr: 2.5000e-04
# Epoch 18/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0440 - root_mean_squared_error: 0.0619 - val_loss: 0.0547 - val_root_mean_squared_error: 0.0830 - lr: 2.5000e-04
# Epoch 19/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0435 - root_mean_squared_error: 0.0613 - val_loss: 0.0547 - val_root_mean_squared_error: 0.0827 - lr: 2.5000e-04
# Epoch 20/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0431 - root_mean_squared_error: 0.0610 - val_loss: 0.0548 - val_root_mean_squared_error: 0.0825 - lr: 2.5000e-04
# Epoch 21/200
# 274/274 [==============================] - 5s 18ms/step - loss: 0.0428 - root_mean_squared_error: 0.0607 - val_loss: 0.0537 - val_root_mean_squared_error: 0.0819 - lr: 1.2500e-04
# Epoch 22/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0423 - root_mean_squared_error: 0.0605 - val_loss: 0.0532 - val_root_mean_squared_error: 0.0816 - lr: 1.2500e-04
# Epoch 23/200
# 274/274 [==============================] - 5s 18ms/step - loss: 0.0425 - root_mean_squared_error: 0.0603 - val_loss: 0.0533 - val_root_mean_squared_error: 0.0815 - lr: 1.2500e-04
# Epoch 24/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0423 - root_mean_squared_error: 0.0602 - val_loss: 0.0530 - val_root_mean_squared_error: 0.0813 - lr: 1.2500e-04
# Epoch 25/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0419 - root_mean_squared_error: 0.0599 - val_loss: 0.0528 - val_root_mean_squared_error: 0.0812 - lr: 1.2500e-04
# Epoch 26/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0419 - root_mean_squared_error: 0.0598 - val_loss: 0.0524 - val_root_mean_squared_error: 0.0809 - lr: 1.2500e-04
# Epoch 27/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0418 - root_mean_squared_error: 0.0597 - val_loss: 0.0525 - val_root_mean_squared_error: 0.0808 - lr: 1.2500e-04
# Epoch 28/200
# 274/274 [==============================] - 5s 18ms/step - loss: 0.0417 - root_mean_squared_error: 0.0595 - val_loss: 0.0523 - val_root_mean_squared_error: 0.0807 - lr: 1.2500e-04
# Epoch 29/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0415 - root_mean_squared_error: 0.0595 - val_loss: 0.0522 - val_root_mean_squared_error: 0.0805 - lr: 1.2500e-04
# Epoch 30/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0414 - root_mean_squared_error: 0.0593 - val_loss: 0.0520 - val_root_mean_squared_error: 0.0804 - lr: 1.2500e-04
# Epoch 31/200
# 274/274 [==============================] - 7s 27ms/step - loss: 0.0411 - root_mean_squared_error: 0.0590 - val_loss: 0.0516 - val_root_mean_squared_error: 0.0801 - lr: 6.2500e-05
# Epoch 32/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0410 - root_mean_squared_error: 0.0589 - val_loss: 0.0515 - val_root_mean_squared_error: 0.0801 - lr: 6.2500e-05
# Epoch 33/200
# 274/274 [==============================] - 5s 18ms/step - loss: 0.0409 - root_mean_squared_error: 0.0586 - val_loss: 0.0515 - val_root_mean_squared_error: 0.0800 - lr: 6.2500e-05
# Epoch 34/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0410 - root_mean_squared_error: 0.0589 - val_loss: 0.0513 - val_root_mean_squared_error: 0.0799 - lr: 6.2500e-05
# Epoch 35/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0408 - root_mean_squared_error: 0.0587 - val_loss: 0.0514 - val_root_mean_squared_error: 0.0799 - lr: 6.2500e-05
# Epoch 36/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0407 - root_mean_squared_error: 0.0585 - val_loss: 0.0513 - val_root_mean_squared_error: 0.0797 - lr: 6.2500e-05
# Epoch 37/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0408 - root_mean_squared_error: 0.0587 - val_loss: 0.0511 - val_root_mean_squared_error: 0.0796 - lr: 6.2500e-05
# Epoch 38/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0407 - root_mean_squared_error: 0.0587 - val_loss: 0.0510 - val_root_mean_squared_error: 0.0795 - lr: 6.2500e-05
# Epoch 39/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0405 - root_mean_squared_error: 0.0583 - val_loss: 0.0510 - val_root_mean_squared_error: 0.0795 - lr: 6.2500e-05
# Epoch 40/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0404 - root_mean_squared_error: 0.0583 - val_loss: 0.0509 - val_root_mean_squared_error: 0.0793 - lr: 6.2500e-05
# Epoch 41/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0403 - root_mean_squared_error: 0.0581 - val_loss: 0.0507 - val_root_mean_squared_error: 0.0793 - lr: 3.1250e-05
# Epoch 42/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0403 - root_mean_squared_error: 0.0580 - val_loss: 0.0507 - val_root_mean_squared_error: 0.0793 - lr: 3.1250e-05
# Epoch 43/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0402 - root_mean_squared_error: 0.0581 - val_loss: 0.0505 - val_root_mean_squared_error: 0.0792 - lr: 3.1250e-05
# Epoch 44/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0402 - root_mean_squared_error: 0.0580 - val_loss: 0.0506 - val_root_mean_squared_error: 0.0792 - lr: 3.1250e-05
# Epoch 45/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0401 - root_mean_squared_error: 0.0580 - val_loss: 0.0505 - val_root_mean_squared_error: 0.0792 - lr: 3.1250e-05
# Epoch 46/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0403 - root_mean_squared_error: 0.0581 - val_loss: 0.0505 - val_root_mean_squared_error: 0.0791 - lr: 3.1250e-05
# Epoch 47/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0400 - root_mean_squared_error: 0.0577 - val_loss: 0.0505 - val_root_mean_squared_error: 0.0791 - lr: 3.1250e-05
# Epoch 48/200
# 274/274 [==============================] - 8s 30ms/step - loss: 0.0400 - root_mean_squared_error: 0.0578 - val_loss: 0.0504 - val_root_mean_squared_error: 0.0791 - lr: 3.1250e-05
# Epoch 49/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0400 - root_mean_squared_error: 0.0579 - val_loss: 0.0504 - val_root_mean_squared_error: 0.0790 - lr: 3.1250e-05
# Epoch 50/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0402 - root_mean_squared_error: 0.0581 - val_loss: 0.0503 - val_root_mean_squared_error: 0.0789 - lr: 3.1250e-05
# Epoch 51/200
# 274/274 [==============================] - 5s 18ms/step - loss: 0.0401 - root_mean_squared_error: 0.0580 - val_loss: 0.0502 - val_root_mean_squared_error: 0.0789 - lr: 1.5625e-05
# Epoch 52/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0398 - root_mean_squared_error: 0.0576 - val_loss: 0.0502 - val_root_mean_squared_error: 0.0788 - lr: 1.5625e-05
# Epoch 53/200
# 274/274 [==============================] - 5s 18ms/step - loss: 0.0401 - root_mean_squared_error: 0.0580 - val_loss: 0.0501 - val_root_mean_squared_error: 0.0788 - lr: 1.5625e-05
# Epoch 54/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0398 - root_mean_squared_error: 0.0575 - val_loss: 0.0501 - val_root_mean_squared_error: 0.0788 - lr: 1.5625e-05
# Epoch 55/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0398 - root_mean_squared_error: 0.0576 - val_loss: 0.0500 - val_root_mean_squared_error: 0.0788 - lr: 1.5625e-05
# Epoch 56/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0400 - root_mean_squared_error: 0.0577 - val_loss: 0.0501 - val_root_mean_squared_error: 0.0787 - lr: 1.5625e-05
# Epoch 57/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0397 - root_mean_squared_error: 0.0576 - val_loss: 0.0500 - val_root_mean_squared_error: 0.0787 - lr: 1.5625e-05
# Epoch 58/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0399 - root_mean_squared_error: 0.0576 - val_loss: 0.0500 - val_root_mean_squared_error: 0.0787 - lr: 1.5625e-05
# Epoch 59/200
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0399 - root_mean_squared_error: 0.0576 - val_loss: 0.0499 - val_root_mean_squared_error: 0.0786 - lr: 1.5625e-05
# Epoch 60/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0398 - root_mean_squared_error: 0.0576 - val_loss: 0.0500 - val_root_mean_squared_error: 0.0786 - lr: 1.5625e-05
# Epoch 61/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0398 - root_mean_squared_error: 0.0577 - val_loss: 0.0499 - val_root_mean_squared_error: 0.0786 - lr: 7.8125e-06
# Epoch 62/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0399 - root_mean_squared_error: 0.0577 - val_loss: 0.0498 - val_root_mean_squared_error: 0.0786 - lr: 7.8125e-06
# Epoch 63/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0397 - root_mean_squared_error: 0.0577 - val_loss: 0.0498 - val_root_mean_squared_error: 0.0785 - lr: 7.8125e-06
# Epoch 64/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0399 - root_mean_squared_error: 0.0578 - val_loss: 0.0498 - val_root_mean_squared_error: 0.0785 - lr: 7.8125e-06
# Epoch 65/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0497 - val_root_mean_squared_error: 0.0785 - lr: 7.8125e-06
# Epoch 66/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0398 - root_mean_squared_error: 0.0576 - val_loss: 0.0497 - val_root_mean_squared_error: 0.0785 - lr: 7.8125e-06
# Epoch 67/200
# 274/274 [==============================] - 6s 20ms/step - loss: 0.0398 - root_mean_squared_error: 0.0576 - val_loss: 0.0497 - val_root_mean_squared_error: 0.0785 - lr: 7.8125e-06
# Epoch 68/200
# 274/274 [==============================] - 7s 24ms/step - loss: 0.0398 - root_mean_squared_error: 0.0577 - val_loss: 0.0497 - val_root_mean_squared_error: 0.0785 - lr: 7.8125e-06
# Epoch 69/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0397 - root_mean_squared_error: 0.0575 - val_loss: 0.0497 - val_root_mean_squared_error: 0.0785 - lr: 7.8125e-06
# Epoch 70/200
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0398 - root_mean_squared_error: 0.0577 - val_loss: 0.0498 - val_root_mean_squared_error: 0.0785 - lr: 7.8125e-06
# Epoch 71/200
# 274/274 [==============================] - 6s 20ms/step - loss: 0.0397 - root_mean_squared_error: 0.0576 - val_loss: 0.0497 - val_root_mean_squared_error: 0.0784 - lr: 3.9063e-06
# Epoch 72/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0396 - root_mean_squared_error: 0.0575 - val_loss: 0.0497 - val_root_mean_squared_error: 0.0784 - lr: 3.9063e-06
# Epoch 73/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0398 - root_mean_squared_error: 0.0577 - val_loss: 0.0497 - val_root_mean_squared_error: 0.0784 - lr: 3.9063e-06
# Epoch 74/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0397 - root_mean_squared_error: 0.0577 - val_loss: 0.0497 - val_root_mean_squared_error: 0.0784 - lr: 3.9063e-06
# Epoch 75/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0397 - root_mean_squared_error: 0.0575 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0784 - lr: 3.9063e-06
# Epoch 76/200
# 274/274 [==============================] - 7s 24ms/step - loss: 0.0397 - root_mean_squared_error: 0.0575 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0784 - lr: 3.9063e-06
# Epoch 77/200
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0395 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0784 - lr: 3.9063e-06
# Epoch 78/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0397 - root_mean_squared_error: 0.0576 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0784 - lr: 3.9063e-06
# Epoch 79/200
# 274/274 [==============================] - 7s 24ms/step - loss: 0.0397 - root_mean_squared_error: 0.0576 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0784 - lr: 3.9063e-06
# Epoch 80/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0784 - lr: 3.9063e-06
# Epoch 81/200
# 274/274 [==============================] - 6s 24ms/step - loss: 0.0396 - root_mean_squared_error: 0.0577 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 1.9531e-06
# Epoch 82/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0396 - root_mean_squared_error: 0.0575 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 1.9531e-06
# Epoch 83/200
# 274/274 [==============================] - 7s 24ms/step - loss: 0.0395 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 1.9531e-06
# Epoch 84/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 1.9531e-06
# Epoch 85/200
# 274/274 [==============================] - 7s 24ms/step - loss: 0.0396 - root_mean_squared_error: 0.0573 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 1.9531e-06
# Epoch 86/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0399 - root_mean_squared_error: 0.0578 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 1.9531e-06
# Epoch 87/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0396 - root_mean_squared_error: 0.0575 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 1.9531e-06
# Epoch 88/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0396 - root_mean_squared_error: 0.0575 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 1.9531e-06
# Epoch 89/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 1.9531e-06
# Epoch 90/200
# 274/274 [==============================] - 7s 24ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 1.9531e-06
# Epoch 91/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0397 - root_mean_squared_error: 0.0577 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 9.7656e-07
# Epoch 92/200
# 274/274 [==============================] - 6s 22ms/step - loss: 0.0398 - root_mean_squared_error: 0.0576 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 9.7656e-07
# Epoch 93/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0395 - root_mean_squared_error: 0.0573 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 9.7656e-07
# Epoch 94/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0397 - root_mean_squared_error: 0.0578 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 9.7656e-07
# Epoch 95/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 9.7656e-07
# Epoch 96/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 9.7656e-07
# Epoch 97/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 9.7656e-07
# Epoch 98/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0395 - root_mean_squared_error: 0.0573 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 9.7656e-07
# Epoch 99/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0396 - root_mean_squared_error: 0.0575 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 9.7656e-07
# Epoch 100/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 9.7656e-07
# Epoch 101/200
# 274/274 [==============================] - 5s 20ms/step - loss: 0.0395 - root_mean_squared_error: 0.0575 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 4.8828e-07
# Epoch 102/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0397 - root_mean_squared_error: 0.0576 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 4.8828e-07
# Epoch 103/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 4.8828e-07
# Epoch 104/200
# 274/274 [==============================] - 6s 23ms/step - loss: 0.0396 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 4.8828e-07
# Epoch 105/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0396 - root_mean_squared_error: 0.0575 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 4.8828e-07
# Epoch 106/200
# 274/274 [==============================] - 6s 21ms/step - loss: 0.0395 - root_mean_squared_error: 0.0574 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 4.8828e-07
# Epoch 107/200
# 274/274 [==============================] - 5s 19ms/step - loss: 0.0396 - root_mean_squared_error: 0.0575 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0783 - lr: 4.8828e-07

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])#??????
plt.title('')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['train','test'], loc='upper right')#????????
plt.show()

# %% [markdown]
# *   Las flucutaciones no son un problema puede deberse a que el modelo ajusta sus parámetros y explora el espacio de datos.
# *   Las curvas convergen a un valor menor y se estabilizan con la época , lo que puede indicar que el modelo está acercandose a un nivel óptimo

# %%
Y_prediction = testScaler.inverse_transform(np.hstack(((model.predict(x_test).reshape(-1, 1), np.zeros((np.size(y_test),nfeatures -1))))))[:, 0]

y_test_inv=testScaler.inverse_transform(np.hstack(((y_test.reshape(-1, 1), np.zeros((np.size(y_test),nfeatures -1))))))[:, 0]
#se calcula mse
mse=mean_squared_error( y_test_inv, Y_prediction)
#raiz cuadrado del mse
rmse=np.sqrt(mse)#error promedio
#error maximo entre y_val_inv e y_prediction
maxError_=max_error(y_test_inv, Y_prediction)
#coeficiente de determinacion r cuadrado
#indica la proporción de la varianza en las etiquetas de validación
#que puede explicarse por el modelo. Un valor de R-cuadrado cercano a 1 indica un buen ajuste del modelo.
r2_=r2_score(y_test_inv, Y_prediction)
print( "MSE: " + str(mse)+" RMSE:" + str(rmse  ))
print( "MaxError: " + str(maxError_)+" R2:" + str(r2_  ))
# Out:
# 57/57 [==============================] - 1s 15ms/step
# MSE: 0.42526273486850724 RMSE:0.6521217178322672
# MaxError: 4.286462474763392 R2:0.9033864804418916

# %%
df=test[['nivel']][ tamanio_ventana:]
# se crea una figura f y el eje ax
f, ax = plt.subplots(figsize=(15,5))
#graficos de lineas con datos de df y eje ax
sns.lineplot(data =df,ax=ax)
#Formato de fechas
#objeto localizador coloca marcas menores cada 3 meses
fmt_month = mdates.MonthLocator(interval=3)
# Minor ticks every year.
#marcas cada anho
fmt_year = mdates.YearLocator()

ax.xaxis.set_minor_locator(fmt_month)
# '%b' to get the names of the month Muestra los meses como Ene, Feb ..
ax.xaxis.set_minor_formatter(mdates.DateFormatter('%b'))
ax.xaxis.set_major_locator(fmt_year)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

# fontsize for month labels
ax.tick_params(labelsize=15, which='both') #tamanho de fuente de las etiquetas de marcas
    # create a second x-axis beneath the first x-axis to show the year in YYYY format
    #el eje se coloca por debajo al principal
sec_xaxis = ax.secondary_xaxis(-0.1)
sec_xaxis.xaxis.set_major_locator(fmt_year)
sec_xaxis.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

    # Hide the second x-axis spines and ticks
sec_xaxis.spines['bottom'].set_visible(False)
sec_xaxis.tick_params(length=0, labelsize=15)

ax.set_ylabel('Nivel Asunción (M)')
ax.set_xlabel('')

ax.set_xlim(df.index[0],df.index[-1])
j=0
mse=[]
maxe=[]
t=[]
    #El bucle itera sobre los valores predichos (Y_prediction) con un paso de horizonte.
for i in range(0, len(Y_prediction),horizonte):
  if(j%5==0 and (j+horizonte)<len(df)): #si j es divisible por 5 calcula mse , maxErr de
        #los valores reales de df.nivel[j:(j+horizonte)]) y valores predichos Y_prediction[i:i+horizonte]
    mse.append(mean_squared_error(np.array(df.nivel[j:(j+horizonte)]), Y_prediction[i:i+horizonte]))
    maxe.append(max_error(np.array(df.nivel[j:(j+horizonte)]), Y_prediction[i:i+horizonte]))
    t.append(df.index[j])

    plt.plot(df.index[j:(j+horizonte)], Y_prediction[i:i+horizonte], color='red')
  j=j+1

plt.show()
